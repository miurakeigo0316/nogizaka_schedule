# %%
import pandas as pd
import japanize_matplotlib

df = pd.read_csv('sales_data.csv')
df_groupby_region_sum = round(df.groupby('地域')['金額'].sum())
df_groupby_region_sum.plot(kind='bar')
# Out:
# <Axes: xlabel='地域'>

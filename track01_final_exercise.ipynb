# %%
import csv

csv_path="t01_customers.csv"

with open(csv_path,mode="r",encoding="utf-8") as file:
    reader=csv.DictReader(file)
    for row in reader:
        print(f"{row["社名"]}")
        print(f"{row["担当者名"]}様")
        print()
        print(f"いつもお世話になっております。")
        print(f"いつもお世話になっております。鈴木 ルタンです。")
        print(f"株式会社TeamSpartaの鈴木 ルタンです。")
        print(f"この度は弊社の{row["案内"]}についてご案内差し上げます")
        print(f"もしご興味があればご返信ください。")
        print(f"以上、よろしくお願いいたします。")
        print(f"--------------")
        print()
# Out:
# スパルタ株式会社
# スパルタ太郎様
#
# いつもお世話になっております。
# いつもお世話になっております。鈴木 ルタンです。
# 株式会社TeamSpartaの鈴木 ルタンです。
# この度は弊社のウェビナーについてご案内差し上げます
# もしご興味があればご返信ください。
# 以上、よろしくお願いいたします。
# --------------
#
# 株式会社スパルタ
# スパルタ花子様
#
# いつもお世話になっております。
# いつもお世話になっております。鈴木 ルタンです。
# 株式会社TeamSpartaの鈴木 ルタンです。
# この度は弊社の商品説明会についてご案内差し上げます
# もしご興味があればご返信ください。
# 以上、よろしくお願いいたします。
# --------------
#
# ルタスパ株式会社
# スパルタ次郎様
#
# いつもお世話になっております。
# いつもお世話になっております。鈴木 ルタンです。
# 株式会社TeamSpartaの鈴木 ルタンです。
# この度は弊社の展示会についてご案内差し上げます
# もしご興味があればご返信ください。
# 以上、よろしくお願いいたします。
# --------------
#
# 株式会社ルタスパ
# スパルタ美咲様
#
# いつもお世話になっております。
# いつもお世話になっております。鈴木 ルタンです。
# 株式会社TeamSpartaの鈴木 ルタンです。
# この度は弊社のウェビナーについてご案内差し上げます
# もしご興味があればご返信ください。
# 以上、よろしくお願いいたします。
# --------------
#
# 株式会社ルタン
# スパルタ大地様
#
# いつもお世話になっております。
# いつもお世話になっております。鈴木 ルタンです。
# 株式会社TeamSpartaの鈴木 ルタンです。
# この度は弊社の商品説明会についてご案内差し上げます
# もしご興味があればご返信ください。
# 以上、よろしくお願いいたします。
# --------------
